# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
# Cargamos el dataset CSV
data = pd.read_csv("car-dataset/Car details v4.csv")
# Creamos una instancia de LabelEncoder
encoder = LabelEncoder()

# Codificamos las variables categóricas
for col in data.columns:
    if data[col].dtype == "object":
        data[col] = encoder.fit_transform(data[col])
# Características
X = data[["make", "model", "year", "kilometer", "fuel type", "transmission", "engine", "max power", "max torque", "drivetrain", "length", "width", "height", "seatingCapacity", "fuelTankCapacity"]]

# Objetivo (precio)
y = data["price"]
# Dividimos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Creamos el modelo de regresión aleatoria
model = RandomForestRegressor()

# Entrenamos el modelo con los datos de entrenamiento
model.fit(X_train, y_train)
# Predecimos el precio en el conjunto de prueba
y_pred = model.predict(X_test)
from sklearn.metrics import mean_absolute_error

# Calculamos el error medio absoluto
mae = mean_absolute_error(y_test, y_pred)

print(f"Error medio absoluto (MAE): {mae:.2f}")
import matplotlib.pyplot as plt

# Visualizamos la distribución de los errores
plt.hist(y_test - y_pred)
plt.xlabel("Error")
plt.ylabel("Frecuencia")
plt.title("Distribución de los errores")
plt.show()
def obtener_datos_usuario():
  """
  Función para recopilar los datos del usuario.

  Devuelve:
      Un diccionario con las características introducidas por el usuario.
  """
  make = input("Introduce la marca del coche: ")
  model = input("Introduce el modelo del coche: ")
  year = int(input("Introduce el año del coche: "))
  kilometer = int(input("Introduce el kilometraje del coche: "))
  fuel_type = input("Introduce el tipo de combustible")

def preprocesar_datos_usuario(datos_usuario):
  """
  Función para preprocesar los datos introducidos por el usuario.

  Argumentos:
      datos_usuario (diccionario): Diccionario con las características introducidas por el usuario.

  Devuelve:
      Un array de NumPy con las características preprocesadas.
  """
  # Codificamos las variables categóricas
  for col in datos_usuario.keys():
    if col in encoder.classes_:
      datos_usuario[col] = encoder.transform([datos_usuario[col]])[0]

  # Convertimos el diccionario a array de NumPy
  datos_usuario = np.array([list(datos_usuario.values())])
  return datos_usuario

def predecir_precio(datos_usuario):
  """
  Función para predecir el precio del coche del usuario.

  Argumentos:
      datos_usuario (array de NumPy): Array con las características preprocesadas del coche del usuario.

  Devuelve:
      El precio predicho del coche.
  """
  # Predecimos el precio
  precio_pred = model.predict(datos_usuario)
  return precio_pred[0]

def main():
  """
  Función principal para la interfaz de usuario.
  """
  # Recopilamos los datos del usuario
  datos_usuario = obtener_datos_usuario()

  # Preprocesamos los datos del usuario
  datos_usuario_preprocesados = preprocesar_datos_usuario(datos_usuario)

  # Predecimos el precio
  precio_pred = predecir_precio(datos_usuario_preprocesados)

  # Mostramos el precio predicho al usuario
  print(f"El precio predicho para el coche es de {precio_pred:.2f} euros.")

if __name__ == "__main__":
  main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 16
#      14         data[col] = encoder.fit_transform(data[col])
#      15 # Características
# ---> 16 X = data[["make", "model", "year", "kilometer", "fuelType", "transmission", "engine", "maxPower", "maxTorque", "drivetrain", "length", "width", "height", "seatingCapacity", "fuelTankCapacity"]]
#      18 # Objetivo (precio)
#      19 y = data["price"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# ...
